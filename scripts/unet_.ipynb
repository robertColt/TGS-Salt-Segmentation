# %%
from keras.layers import Conv2D, MaxPool2D, Input, Activation, Conv2DTranspose, concatenate, BatchNormalization
from keras.models import Model,load_model
from keras.optimizers import Adam, SGD
# Out:
# Using TensorFlow backend.

# %%
def conv2d_block(input_tensor, n_filters, kernel_size=3):
    # first layer
    c1 = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(input_tensor)
    c1 = BatchNormalization()(c1)
    c1 = Activation("elu")(c1)
    return c2

  
def residual_block(blockInput, num_filters=16, batch_activate = False):
    x = BatchActivate(blockInput)
    x = conv2d_block(x, num_filters, (3,3) )
    x = conv2d_block(x, num_filters, (3,3), activation=False)
    x = Add()([x, blockInput])
    if batch_activate:
        x = BatchActivate(x)
    return x

# %%
def unet_resnet_model(in_shape):
  inputs = Input(in_shape)
  
  c1 =
