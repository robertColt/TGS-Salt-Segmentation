# %%
cd '/content/drive/My Drive/Kaggle/TGS-Salt-Segmentation'
# Out:
# /content/drive/My Drive/Kaggle/TGS-Salt-Segmentation

# %%
# !git config --global user.email "coltrobi@gmail.com"
# !git config --global user.name "Robert Colt"

# %%
# !git add .

# %%
# !git commit -m 'changed unet resnet to be ready for train'
# Out:
# [master cc82ce0] changed unet resnet to be ready for train
#  5 files changed, 9 insertions(+), 1154 deletions(-)
#  create mode 100644 git notebook.ipynb
#  rewrite scripts/model_testing.ipynb (100%)
#  rewrite scripts/model_train.ipynb (98%)
#  rewrite scripts/unet_resnet_101_adam_lovasz-loss_iou-metric.ipynb (99%)

# %%
# !git pull
# Out:
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 13 (delta 6), reused 10 (delta 6), pack-reused 3
# Unpacking objects: 100% (13/13), done.
# From https://github.com/robiColt/TGS-Salt-Segmentation
#    255558c..9feeb5b  master     -> origin/master
# Auto-merging scripts/unet_resnet_101_adam_lovasz-loss_iou-metric.ipynb
# CONFLICT (content): Merge conflict in scripts/unet_resnet_101_adam_lovasz-loss_iou-metric.ipynb
# Auto-merging scripts/model_testing.ipynb
# CONFLICT (content): Merge conflict in scripts/model_testing.ipynb
# Auto-merging .gitignore
# CONFLICT (content): Merge conflict in .gitignore
# Automatic merge failed; fix conflicts and then commit the result.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
